# %% [markdown]
# # Task 1
#
# Obtain by simulations the tail of the normalized sum of n i.i.d. Symmetric Bernoulli, as a function of t for 3 different values of n. Then plot them along with the theoretical bound on the same tail found in the lecture notes. Is the the derived theoretical bound correct? Is it tight?

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import math

from typing import Callable, List


random.seed(0)
np.random.seed(0) 

NUM_TRIALS = 5000

# %%
import lab2_funcs
import importlib
importlib.reload(lab2_funcs)
from lab2_funcs import task1

# %%
task1(NUM_TRIALS)

# %% [markdown]
# The theoretical and empirical tail distributions of the normalized sum of n i.i.d. Symmetric Bernoulli random variables suggest the the theoretical bound is indeed tight. It is important to keep in mind that the theoretical bound:
#
# $$
#     P(X \geq t) \leq  \exp \left( - \frac{t^2}{2} \right)
# $$
#
# is concerned mainly with large values of t (s.t $ | t - \mu|  \geq \sigma $) which would explain how the gap between the empirical and theoretical tail distributions is larger for small values of t but closes very quickly as t increases.

# %% [markdown]
# # Task 2

# %%
import lab2_funcs
import importlib
importlib.reload(lab2_funcs)
from lab2_funcs import task2

# %%
task2(NUM_TRIALS, 100)

# %% [markdown]
# # Task 3

# %%
importlib.reload(lab2_funcs)
from lab2_funcs import task3
task3(100, 100, 10)

# %%
importlib.reload(lab2_funcs)
from lab2_funcs import task4
task4(100, 100, 10)

# %%
importlib.reload(lab2_funcs)
from lab2_funcs import task5
task5(100, 100, 10)
